# %%
import torch
#from network_seg import P3D199
import network_seg
import hiddenlayer as hl


model = network_seg.P3D199()
g = hl.build_graph(model, torch.zeros([4, 3, 16, 224, 224]))
g
# Out:
# /disk2/yangle/software/anaconda3/envs/p3d/lib/python3.6/site-packages/matplotlib/colors.py:680: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   not cbook.is_string_like(colors[0]):
# /disk2/yangle/software/anaconda3/envs/p3d/lib/python3.6/site-packages/torch/onnx/utils.py:501: UserWarning: ONNX export failed on ATen operator upsample_trilinear3d because torch.onnx.symbolic.upsample_trilinear3d does not exist
#   .format(op_name, op_name))
